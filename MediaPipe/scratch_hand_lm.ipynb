# %%
import mediapipe as mp
from mediapipe.tasks import python
from mediapipe.tasks.python import vision
import cv2
import numpy as np
from mediapipe import solutions
from mediapipe.framework.formats import landmark_pb2
import cvzone
import os

# %%
class HandLandmarker:
    def __init__(self, model_path):
        self.model_path = model_path
        self.base_options = python.BaseOptions(model_asset_path=self.model_path)
        self.options = vision.HandLandmarkerOptions(base_options=self.base_options, num_hands=2)
        self.detector = vision.HandLandmarker.create_from_options(self.options)
        self.saving_path = 'anaconda_projects/mediapipe_hand'
        os.makedirs(self.saving_path, exist_ok=True)
        self.watch_path = 'FREE-Watch-Clipart.png'
        self.watch_image = cv2.imread(self.watch_path, cv2.IMREAD_UNCHANGED)
        if self.watch_image is None:
            print(f"Warning: Unable to load watch image from {self.watch_path}")

        flag = True
        while flag:
            choice = input("""
Enter your choice to proceed:
1: Image
2: Video
3: WebCam
0: Exit
>""")
            if choice == '0':
                print('Good bye!')
                flag = False
            elif choice == '1':
                try:
                    self.process_image()
                except FileNotFoundError:
                    print('Some of the files not found on defined path.')
                except Exception as e:
                    print(f'An error occurred: {e}')

            elif choice == '2':
                try:
                    self.process_video()
                except FileNotFoundError:
                    print('Some of the files not found on defined path.')
                except Exception as e:
                    print(f'An error occurred: {e}')

            elif choice == '3':
                try:
                    self.process_webcam()
                except FileNotFoundError:
                    print('Some of the files not found on defined path.')
                except Exception as e:
                    print(f'An error occurred: {e}')

            else:
                print('Invalid choice! Please enter a valid option.')

    def process_image(self):
        path_choice = input('''
What do you want to provide?
1: Image path (for a single image)
2: Folder path (for multiple images)
0: Exit to main menu
>''')
        if path_choice == '1':
            image_path = input('Enter the image path:\n>')
            image_path_list = [image_path]
            print('Processing image...')
        elif path_choice == '2':
            folder_path = input('Enter the folder path:\n>')
            image_path_list = [os.path.join(folder_path, img) for img in os.listdir(folder_path)]
            print(image_path_list)
            print('Processing images...')
        elif path_choice == '0':
            print('Redirecting to main menu...')
            return
        else:
            print('Invalid choice! Redirecting to main menu...')
            return

        image_count = 1
        for image_path in image_path_list:
            lh_count, rh_count = 0, 0
            lw_coordinates, rw_coordinates = [], []
            rt_coordinates, ri_coordinates, rm_coordinates, rr_coordinates, rl_coordinates = [], [], [], [], []

            image_path = image_path.replace('"', '').replace("'", '')
            self.mp_image = mp.Image.create_from_file(image_path)
            self.result = self.detector.detect(self.mp_image)

            handedness_list = self.result.handedness
            hand_landmarks_list = self.result.hand_landmarks
            image = cv2.imread(image_path)

            if image is None:
                print(f"Failed to read image at {image_path}")
                continue

            if image_path[-4:] == '.png':
                image = cv2.cvtColor(image, cv2.COLOR_RGBA2RGB)

            height, width, _ = image.shape

            if len(handedness_list) > 0:
                for i in range(len(handedness_list)):
                    if handedness_list[i][0].category_name == 'Left':
                        lh_count += 1
                        keypoints_x = [landmark.x * width for landmark in hand_landmarks_list[i]]
                        keypoints_y = [landmark.y * height for landmark in hand_landmarks_list[i]]
                        wrist_x = keypoints_x[0]
                        wrist_y = keypoints_y[0]
                        lw_coordinates.append((wrist_x, wrist_y))

                        for j in range(len(keypoints_x)):
                            cv2.circle(img=image, center=(int(keypoints_x[j]), int(keypoints_y[j])), radius=4, color=(0, 255, 0), thickness=-2)

                        x_min = min(keypoints_x)
                        y_min = min(keypoints_y)
                        x_max = max(keypoints_x)
                        y_max = max(keypoints_y)
                        cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 0, 255), 1)
                        cv2.putText(image, "Left", (int(x_min), int(y_min - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
                    else:
                        rh_count += 1
                        keypoints_x = [landmark.x * width for landmark in hand_landmarks_list[i]]
                        keypoints_y = [landmark.y * height for landmark in hand_landmarks_list[i]]
                        wrist_x = keypoints_x[0]
                        wrist_y = keypoints_y[0]
                        rw_coordinates.append((wrist_x, wrist_y))

                        rt_coordinates.append((keypoints_x[2], keypoints_y[2]))
                        ri_coordinates.append((keypoints_x[5], keypoints_y[5]))
                        rm_coordinates.append((keypoints_x[9], keypoints_y[9]))
                        rr_coordinates.append((keypoints_x[13], keypoints_y[13]))
                        rl_coordinates.append((keypoints_x[17], keypoints_y[17]))

                        rt_rl = rt_coordinates[0][0] - rl_coordinates[0][0]
                        tan_theta = (rm_coordinates[0][1] - rw_coordinates[0][1]) / (rm_coordinates[0][0] - rw_coordinates[0][0]) if (rm_coordinates[0][0] - rw_coordinates[0][0]) != 0 else 0
                        theta = np.arctan(tan_theta)
                        theta_degrees = np.degrees(theta)

                        if rw_coordinates[0][1] > ri_coordinates[0][1] and rw_coordinates[0][1] > rm_coordinates[0][1] and rw_coordinates[0][1] > rr_coordinates[0][1]:
                            hand_orientation = 'straight'
                            hand_view = 'palm' if rt_rl > 0 else 'dorsum'
                        else:
                            hand_orientation = 'rotated'
                            hand_view = 'dorsum' if rt_rl > 0 else 'palm'

                        if hand_view == 'dorsum' and self.watch_image is not None:
                            x_min = min(keypoints_x)
                            y_min = min(keypoints_y)
                            x_max = max(keypoints_x)
                            y_max = max(keypoints_y)
                            watch_resized = cv2.resize(self.watch_image, (int(x_max - x_min) // 2, int(x_max - x_min) // 2))
                            fit_ymin = int(wrist_y - (watch_resized.shape[0] // 2))
                            fit_xmin = int(wrist_x - (watch_resized.shape[1] // 2))
                            fit_ymax = fit_ymin + watch_resized.shape[0]
                            fit_xmax = fit_xmin + watch_resized.shape[1]

                            if fit_xmin >= 0 and fit_ymin >= 0 and fit_xmax <= width and fit_ymax <= height:
                                M = cv2.getRotationMatrix2D((watch_resized.shape[1] // 2, watch_resized.shape[0] // 2), -theta_degrees, 1)
                                watch_rotated = cv2.warpAffine(watch_resized, M, (watch_resized.shape[1], watch_resized.shape[0]))
                                image = cvzone.overlayPNG(image, watch_rotated, (fit_xmin, fit_ymin))
                        else:
                            for k in range(len(keypoints_x)):
                                cv2.circle(img=image, center=(int(keypoints_x[k]), int(keypoints_y[k])), radius=4, color=(0, 255, 0), thickness=-2)
                            x_min = min(keypoints_x)
                            y_min = min(keypoints_y)
                            x_max = max(keypoints_x)
                            y_max = max(keypoints_y)
                            cv2.rectangle(image, (int(x_min), int(y_min)), (int(x_max), int(y_max)), (0, 0, 255), 1)
                            cv2.putText(image, "Right", (int(x_min), int(y_min - 10)), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

                print(f'Total number of hands detected: {len(handedness_list)}')
                print(f'Left Hand count: {lh_count}')
                print(f'Right Hand count: {rh_count}')
                print(f'Left Wrist coordinates: {lw_coordinates}')
                print(f'Right Wrist coordinates: {rw_coordinates}\n')
                output_path = os.path.join(self.saving_path, f'output_image{image_count}.jpg')
                print(f"Saving processed image at '{output_path}' ...")
                cv2.imwrite(output_path, image)
                print(f'Image saved successfully.')
                image_count += 1
            else:
                print('No hands detected in the image.')

    def process_video(self):
        path_choice = input('''
What do you want to provide?
1: Video path (for a single video)
2: Folder path (for multiple videos)
0: Exit to main menu
>''')
        if path_choice == '0':
            return
        elif path_choice not in ['1', '2']:
            print('Invalid choice.')
            return

        video_paths = []
        if path_choice == '1':
            video_path = input('Enter the video path:\n>').strip().replace('"', '').replace("'", '')
            video_paths.append(video_path)
        elif path_choice == '2':
            folder_path = input('Enter the folder path:\n>').strip().replace('"', '').replace("'", '')
            video_extensions = ['.mp4', '.avi', '.mov', '.mkv', '.flv', '.MP4']
            for filename in os.listdir(folder_path):
                if os.path.splitext(filename)[1].lower() in video_extensions:
                    video_paths.append(os.path.join(folder_path, filename))

        if not video_paths:
            print("No valid video files found.")
            return

        for video_path in video_paths:
            cap = cv2.VideoCapture(video_path)
            if not cap.isOpened():
                print(f"Could not open video {video_path}")
                continue

            fps = cap.get(cv2.CAP_PROP_FPS)
            width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
            height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
            total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))

            output_filename = os.path.basename(video_path)
            output_path = os.path.join(self.saving_path, f'processed_{output_filename}')
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

            frame_count = 0
            while cap.isOpened():
                ret, frame = cap.read()
                if not ret:
                    break

                rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
                mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)
                result = self.detector.detect(mp_image)

                annotated_frame = frame.copy()
                handedness_list = result.handedness
                hand_landmarks_list = result.hand_landmarks

                if len(handedness_list) > 0:
                    for i in range(len(handedness_list)):
                        handedness = handedness_list[i][0].category_name
                        landmarks = hand_landmarks_list[i]

                        keypoints_x = [lm.x * width for lm in landmarks]
                        keypoints_y = [lm.y * height for lm in landmarks]

                        if handedness == 'Left':
                            for j in range(len(keypoints_x)):
                                cv2.circle(annotated_frame, (int(keypoints_x[j]), int(keypoints_y[j])), 4, (0, 255, 0), -2)
                            x_min = int(min(keypoints_x))
                            y_min = int(min(keypoints_y))
                            x_max = int(max(keypoints_x))
                            y_max = int(max(keypoints_y))
                            cv2.rectangle(annotated_frame, (x_min, y_min), (x_max, y_max), (0, 0, 255), 1)
                            cv2.putText(annotated_frame, "Left", (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
                        else:
                            wrist_x = keypoints_x[0]
                            wrist_y = keypoints_y[0]

                            rt_coord = (keypoints_x[2], keypoints_y[2])
                            ri_coord = (keypoints_x[5], keypoints_y[5])
                            rm_coord = (keypoints_x[9], keypoints_y[9])
                            rr_coord = (keypoints_x[13], keypoints_y[13])
                            rl_coord = (keypoints_x[17], keypoints_y[17])

                            rt_rl = rt_coord[0] - rl_coord[0]
                            tan_theta = (rm_coord[1] - wrist_y) / (rm_coord[0] - wrist_x) if (rm_coord[0] - wrist_x) != 0 else 0
                            theta = np.arctan(tan_theta)
                            theta_degrees = np.degrees(theta)

                            if wrist_y > ri_coord[1] and wrist_y > rm_coord[1] and wrist_y > rr_coord[1]:
                                hand_orientation = 'straight'
                                hand_view = 'palm' if rt_rl > 0 else 'dorsum'
                            else:
                                hand_orientation = 'rotated'
                                hand_view = 'dorsum' if rt_rl > 0 else 'palm'

                            if hand_view == 'dorsum' and self.watch_image is not None:
                                x_min = int(min(keypoints_x))
                                y_min = int(min(keypoints_y))
                                x_max = int(max(keypoints_x))
                                y_max = int(max(keypoints_y))

                                watch_resized = cv2.resize(self.watch_image, ((x_max - x_min) // 2, (x_max - x_min) // 2))

                                fit_xmin = int(wrist_x - watch_resized.shape[1] // 2)
                                fit_ymin = int(wrist_y - watch_resized.shape[0] // 2)
                                fit_xmax = fit_xmin + watch_resized.shape[1]
                                fit_ymax = fit_ymin + watch_resized.shape[0]

                                if fit_xmin >= 0 and fit_ymin >= 0 and fit_xmax <= width and fit_ymax <= height:
                                    M = cv2.getRotationMatrix2D((watch_resized.shape[1] // 2, watch_resized.shape[0] // 2), -theta_degrees, 1)
                                    watch_rotated = cv2.warpAffine(watch_resized, M, (watch_resized.shape[1], watch_resized.shape[0]))
                                    annotated_frame = cvzone.overlayPNG(annotated_frame, watch_rotated, (fit_xmin, fit_ymin))
                            else:
                                for k in range(len(keypoints_x)):
                                    cv2.circle(annotated_frame, (int(keypoints_x[k]), int(keypoints_y[k])), 4, (0, 255, 0), -2)
                                x_min = int(min(keypoints_x))
                                y_min = int(min(keypoints_y))
                                x_max = int(max(keypoints_x))
                                y_max = int(max(keypoints_y))
                                cv2.rectangle(annotated_frame, (x_min, y_min), (x_max, y_max), (0, 0, 255), 1)
                                cv2.putText(annotated_frame, "Right", (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

                out.write(annotated_frame)
                frame_count += 1
                print(f"Processed frame {frame_count} of {total_frames}")

            cap.release()
            out.release()
            print(f"Video saved to {output_path}")

    def process_webcam(self):
        cap = cv2.VideoCapture(0)
        if not cap.isOpened():
            print("Error: Could not open webcam.")
            return

        print("Webcam started. Press 'q' to quit.")

        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print("Error: Failed to capture frame.")
                break

            rgb_frame = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=rgb_frame)

            result = self.detector.detect(mp_image)

            annotated_frame = frame.copy()
            handedness_list = result.handedness
            hand_landmarks_list = result.hand_landmarks

            if len(handedness_list) > 0:
                for i in range(len(handedness_list)):
                    handedness = handedness_list[i][0].category_name
                    landmarks = hand_landmarks_list[i]

                    height, width, _ = frame.shape

                    keypoints_x = [lm.x * width for lm in landmarks]
                    keypoints_y = [lm.y * height for lm in landmarks]

                    if handedness == 'Left':
                        for j in range(len(keypoints_x)):
                            cv2.circle(annotated_frame, (int(keypoints_x[j]), int(keypoints_y[j])), 4, (0, 255, 0), -2)
                        x_min = int(min(keypoints_x))
                        y_min = int(min(keypoints_y))
                        x_max = int(max(keypoints_x))
                        y_max = int(max(keypoints_y))
                        cv2.rectangle(annotated_frame, (x_min, y_min), (x_max, y_max), (0, 0, 255), 1)
                        cv2.putText(annotated_frame, "Left", (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)
                    else:
                        wrist_x = keypoints_x[0]
                        wrist_y = keypoints_y[0]

                        rt_coord = (keypoints_x[2], keypoints_y[2])
                        ri_coord = (keypoints_x[5], keypoints_y[5])
                        rm_coord = (keypoints_x[9], keypoints_y[9])
                        rr_coord = (keypoints_x[13], keypoints_y[13])
                        rl_coord = (keypoints_x[17], keypoints_y[17])

                        rt_rl = rt_coord[0] - rl_coord[0]
                        tan_theta = (rm_coord[1] - wrist_y) / (rm_coord[0] - wrist_x) if (rm_coord[0] - wrist_x) != 0 else 0
                        theta = np.arctan(tan_theta)
                        theta_degrees = np.degrees(theta)

                        if wrist_y > ri_coord[1] and wrist_y > rm_coord[1] and wrist_y > rr_coord[1]:
                            hand_orientation = 'straight'
                            hand_view = 'palm' if rt_rl > 0 else 'dorsum'
                        else:
                            hand_orientation = 'rotated'
                            hand_view = 'dorsum' if rt_rl > 0 else 'palm'

                        if hand_view == 'dorsum' and self.watch_image is not None:
                            x_min = int(min(keypoints_x))
                            y_min = int(min(keypoints_y))
                            x_max = int(max(keypoints_x))
                            y_max = int(max(keypoints_y))

                            watch_resized = cv2.resize(self.watch_image, ((x_max - x_min) // 2, (x_max - x_min) // 2))

                            fit_xmin = int(wrist_x - watch_resized.shape[1] // 2)
                            fit_ymin = int(wrist_y - watch_resized.shape[0] // 2)
                            fit_xmax = fit_xmin + watch_resized.shape[1]
                            fit_ymax = fit_ymin + watch_resized.shape[0]

                            if fit_xmin >= 0 and fit_ymin >= 0 and fit_xmax <= width and fit_ymax <= height:
                                M = cv2.getRotationMatrix2D((watch_resized.shape[1] // 2, watch_resized.shape[0] // 2), -theta_degrees, 1)
                                watch_rotated = cv2.warpAffine(watch_resized, M, (watch_resized.shape[1], watch_resized.shape[0]))
                                annotated_frame = cvzone.overlayPNG(annotated_frame, watch_rotated, (fit_xmin, fit_ymin))
                        else:
                            for k in range(len(keypoints_x)):
                                cv2.circle(annotated_frame, (int(keypoints_x[k]), int(keypoints_y[k])), 4, (0, 255, 0), -2)
                            x_min = int(min(keypoints_x))
                            y_min = int(min(keypoints_y))
                            x_max = int(max(keypoints_x))
                            y_max = int(max(keypoints_y))
                            cv2.rectangle(annotated_frame, (x_min, y_min), (x_max, y_max), (0, 0, 255), 1)
                            cv2.putText(annotated_frame, "Right", (x_min, y_min - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.9, (255, 0, 0), 2)

            cv2.imshow("Webcam Feed", annotated_frame)

            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()
        print("Webcam stopped.")

# %%
model_path = 'hand_landmarker.task'
HandLandmarker(model_path)
# Out:
# Enter your choice to proceed:
# 1: Image
# 2: Video
# 3: WebCam
# 0: Exit
# >2
#
# What do you want to provide?
# 1: Video path (for a single video)
# 2: Folder path (for multiple videos)
# 0: Exit to main menu
# >1
# Enter the video path:
# >/content/drive/MyDrive/Colab Notebooks/MediaPipe/videos/Green Screen Hand (20+ Effects 4K _ Free Download Link).mp4
# Processed frame 1 of 1814
# Processed frame 2 of 1814
# Processed frame 3 of 1814
# Processed frame 4 of 1814
# Processed frame 5 of 1814
# Processed frame 6 of 1814
# Processed frame 7 of 1814
# Processed frame 8 of 1814
# Processed frame 9 of 1814
# Processed frame 10 of 1814
# Processed frame 11 of 1814
# Processed frame 12 of 1814
# Processed frame 13 of 1814
# Processed frame 14 of 1814
# Processed frame 15 of 1814
# Processed frame 16 of 1814
# Processed frame 17 of 1814
# Processed frame 18 of 1814
# Processed frame 19 of 1814
# Processed frame 20 of 1814
# Processed frame 21 of 1814
# Processed frame 22 of 1814
# Processed frame 23 of 1814
# Processed frame 24 of 1814
# Processed frame 25 of 1814
# Processed frame 26 of 1814
# Processed frame 27 of 1814
# Processed frame 28 of 1814
# Processed frame 29 of 1814
# Processed frame 30 of 1814
# Processed frame 31 of 1814
# Processed frame 32 of 1814
# Processed frame 33 of 1814
# Processed frame 34 of 1814
# Processed frame 35 of 1814
# Processed frame 36 of 1814
# Processed frame 37 of 1814
# Processed frame 38 of 1814
# Processed frame 39 of 1814
# Processed frame 40 of 1814
# Processed frame 41 of 1814
# Processed frame 42 of 1814
# Processed frame 43 of 1814
# Processed frame 44 of 1814
# Processed frame 45 of 1814
# Processed frame 46 of 1814
# Processed frame 47 of 1814
# Processed frame 48 of 1814
# Processed frame 49 of 1814
# Processed frame 50 of 1814
# Processed frame 51 of 1814
# Processed frame 52 of 1814
# Processed frame 53 of 1814
# Processed frame 54 of 1814
# Processed frame 55 of 1814
# Processed frame 56 of 1814
# Processed frame 57 of 1814
# Processed frame 58 of 1814
# Processed frame 59 of 1814
# Processed frame 60 of 1814
# Processed frame 61 of 1814
# Processed frame 62 of 1814
# Processed frame 63 of 1814
# Processed frame 64 of 1814
# Processed frame 65 of 1814
# Processed frame 66 of 1814
# Processed frame 67 of 1814
# Processed frame 68 of 1814
# Processed frame 69 of 1814
# Processed frame 70 of 1814
# Processed frame 71 of 1814
# Processed frame 72 of 1814
# Processed frame 73 of 1814
# Processed frame 74 of 1814
# Processed frame 75 of 1814
# Processed frame 76 of 1814
# Processed frame 77 of 1814
# Processed frame 78 of 1814
# Processed frame 79 of 1814
# Processed frame 80 of 1814
# Processed frame 81 of 1814
# Processed frame 82 of 1814
# Processed frame 83 of 1814
# Processed frame 84 of 1814
# Processed frame 85 of 1814
# Processed frame 86 of 1814
# Processed frame 87 of 1814
# Processed frame 88 of 1814
# Processed frame 89 of 1814
# Processed frame 90 of 1814
# Processed frame 91 of 1814
# Processed frame 92 of 1814
# Processed frame 93 of 1814
# Processed frame 94 of 1814
# Processed frame 95 of 1814
# Processed frame 96 of 1814
# Processed frame 97 of 1814
# Processed frame 98 of 1814
# Processed frame 99 of 1814
# Processed frame 100 of 1814
# Processed frame 101 of 1814
# Processed frame 102 of 1814
# Processed frame 103 of 1814
# Processed frame 104 of 1814
# Processed frame 105 of 1814
# Processed frame 106 of 1814
# Processed frame 107 of 1814
# Processed frame 108 of 1814
# Processed frame 109 of 1814
# Processed frame 110 of 1814
# Processed frame 111 of 1814
# Processed frame 112 of 1814
# Processed frame 113 of 1814
# Processed frame 114 of 1814
# Processed frame 115 of 1814
# Processed frame 116 of 1814
# Processed frame 117 of 1814
# Processed frame 118 of 1814
# Processed frame 119 of 1814
# Processed frame 120 of 1814
# Processed frame 121 of 1814
# Processed frame 122 of 1814
# Processed frame 123 of 1814
# Processed frame 124 of 1814
# Processed frame 125 of 1814
# Processed frame 126 of 1814
# Processed frame 127 of 1814
# Processed frame 128 of 1814
# Processed frame 129 of 1814
# Processed frame 130 of 1814
# Processed frame 131 of 1814
# Processed frame 132 of 1814
# Processed frame 133 of 1814
# Processed frame 134 of 1814
# Processed frame 135 of 1814
# Processed frame 136 of 1814
# Processed frame 137 of 1814
# Processed frame 138 of 1814
# Processed frame 139 of 1814
# Processed frame 140 of 1814
# Processed frame 141 of 1814
# Processed frame 142 of 1814
# Processed frame 143 of 1814
# Processed frame 144 of 1814
# Processed frame 145 of 1814
# Processed frame 146 of 1814
# Processed frame 147 of 1814
# Processed frame 148 of 1814
# Processed frame 149 of 1814
# Processed frame 150 of 1814
# Processed frame 151 of 1814
# Processed frame 152 of 1814
# Processed frame 153 of 1814
# Processed frame 154 of 1814
# Processed frame 155 of 1814
# Processed frame 156 of 1814
# Processed frame 157 of 1814
# Processed frame 158 of 1814
# Processed frame 159 of 1814
# Processed frame 160 of 1814
# Processed frame 161 of 1814
# Processed frame 162 of 1814
# Processed frame 163 of 1814
# Processed frame 164 of 1814
# Processed frame 165 of 1814
# Processed frame 166 of 1814
# Processed frame 167 of 1814
# Processed frame 168 of 1814
# Processed frame 169 of 1814
# Processed frame 170 of 1814
# Processed frame 171 of 1814
# Processed frame 172 of 1814
# Processed frame 173 of 1814
# Processed frame 174 of 1814
# Processed frame 175 of 1814
# Processed frame 176 of 1814
# Processed frame 177 of 1814
# Processed frame 178 of 1814
# Processed frame 179 of 1814
# Processed frame 180 of 1814
# Processed frame 181 of 1814
# Processed frame 182 of 1814
# Processed frame 183 of 1814
# Processed frame 184 of 1814
# Processed frame 185 of 1814
# Processed frame 186 of 1814
# Processed frame 187 of 1814
# Processed frame 188 of 1814
# Processed frame 189 of 1814
# Processed frame 190 of 1814
# Processed frame 191 of 1814
# Processed frame 192 of 1814
# Processed frame 193 of 1814
# Processed frame 194 of 1814
# Processed frame 195 of 1814
# Processed frame 196 of 1814
# Processed frame 197 of 1814
# Processed frame 198 of 1814
# Processed frame 199 of 1814
# Processed frame 200 of 1814
# Processed frame 201 of 1814
# Processed frame 202 of 1814
# Processed frame 203 of 1814
# Processed frame 204 of 1814
# Processed frame 205 of 1814
# Processed frame 206 of 1814
# Processed frame 207 of 1814
# Processed frame 208 of 1814
# Processed frame 209 of 1814
# Processed frame 210 of 1814
# Processed frame 211 of 1814
# Processed frame 212 of 1814
# Processed frame 213 of 1814
# Processed frame 214 of 1814
# Processed frame 215 of 1814
# Processed frame 216 of 1814
# Processed frame 217 of 1814
# Processed frame 218 of 1814
# Processed frame 219 of 1814
# Processed frame 220 of 1814
# Processed frame 221 of 1814
# Processed frame 222 of 1814
# Processed frame 223 of 1814
# Processed frame 224 of 1814
# Processed frame 225 of 1814
# Processed frame 226 of 1814
# Processed frame 227 of 1814
# Processed frame 228 of 1814
# Processed frame 229 of 1814
# Processed frame 230 of 1814
# Processed frame 231 of 1814
# Processed frame 232 of 1814
# Processed frame 233 of 1814
# Processed frame 234 of 1814
# Processed frame 235 of 1814
# Processed frame 236 of 1814
# Processed frame 237 of 1814
# Processed frame 238 of 1814
# Processed frame 239 of 1814
# Processed frame 240 of 1814
# Processed frame 241 of 1814
# Processed frame 242 of 1814
# Processed frame 243 of 1814
# Processed frame 244 of 1814
# Processed frame 245 of 1814
# Processed frame 246 of 1814
# Processed frame 247 of 1814
# Processed frame 248 of 1814
# Processed frame 249 of 1814
# Processed frame 250 of 1814
# Processed frame 251 of 1814
# Processed frame 252 of 1814
# Processed frame 253 of 1814
# Processed frame 254 of 1814
# Processed frame 255 of 1814
# Processed frame 256 of 1814
# Processed frame 257 of 1814
# Processed frame 258 of 1814
# Processed frame 259 of 1814
# Processed frame 260 of 1814
# Processed frame 261 of 1814
# Processed frame 262 of 1814
# Processed frame 263 of 1814
# Processed frame 264 of 1814
# Processed frame 265 of 1814
# Processed frame 266 of 1814
# Processed frame 267 of 1814
# Processed frame 268 of 1814
# Processed frame 269 of 1814
# Processed frame 270 of 1814
# Processed frame 271 of 1814
# Processed frame 272 of 1814
# Processed frame 273 of 1814
# Processed frame 274 of 1814
# Processed frame 275 of 1814
# Processed frame 276 of 1814
# Processed frame 277 of 1814
# Processed frame 278 of 1814
# Processed frame 279 of 1814
# Processed frame 280 of 1814
# Processed frame 281 of 1814
# Processed frame 282 of 1814
# Processed frame 283 of 1814
# Processed frame 284 of 1814
# Processed frame 285 of 1814
# Processed frame 286 of 1814
# Processed frame 287 of 1814
# Processed frame 288 of 1814
# Processed frame 289 of 1814
# Processed frame 290 of 1814
# Processed frame 291 of 1814
# Processed frame 292 of 1814
# Processed frame 293 of 1814
# Processed frame 294 of 1814
# Processed frame 295 of 1814
# Processed frame 296 of 1814
# Processed frame 297 of 1814
# Processed frame 298 of 1814
# Processed frame 299 of 1814
# Processed frame 300 of 1814
# Processed frame 301 of 1814
# Processed frame 302 of 1814
# Processed frame 303 of 1814
# Processed frame 304 of 1814
# Processed frame 305 of 1814
# Processed frame 306 of 1814
# Processed frame 307 of 1814
# Processed frame 308 of 1814
# Processed frame 309 of 1814
# Processed frame 310 of 1814
# Processed frame 311 of 1814
# Processed frame 312 of 1814
# Processed frame 313 of 1814
# Processed frame 314 of 1814
# Processed frame 315 of 1814
# Processed frame 316 of 1814
# Processed frame 317 of 1814
# Processed frame 318 of 1814
# Processed frame 319 of 1814
# Processed frame 320 of 1814
# Processed frame 321 of 1814
# Processed frame 322 of 1814
# Processed frame 323 of 1814
# Processed frame 324 of 1814
# Processed frame 325 of 1814
# Processed frame 326 of 1814
# Processed frame 327 of 1814
# Processed frame 328 of 1814
# Processed frame 329 of 1814
# Processed frame 330 of 1814
# Processed frame 331 of 1814
# Processed frame 332 of 1814
# Processed frame 333 of 1814
# Processed frame 334 of 1814
# Processed frame 335 of 1814
# Processed frame 336 of 1814
# Processed frame 337 of 1814
# Processed frame 338 of 1814
# Processed frame 339 of 1814
# Processed frame 340 of 1814
# Processed frame 341 of 1814
# Processed frame 342 of 1814
# Processed frame 343 of 1814
# Processed frame 344 of 1814
# Processed frame 345 of 1814
# Processed frame 346 of 1814
# Processed frame 347 of 1814
# Processed frame 348 of 1814
# Processed frame 349 of 1814
# Processed frame 350 of 1814
# Processed frame 351 of 1814
# Processed frame 352 of 1814
# Processed frame 353 of 1814
# Processed frame 354 of 1814
# Processed frame 355 of 1814
# Processed frame 356 of 1814
# Processed frame 357 of 1814
# Processed frame 358 of 1814
# Processed frame 359 of 1814
# Processed frame 360 of 1814
# Processed frame 361 of 1814
# Processed frame 362 of 1814
# Processed frame 363 of 1814
# Processed frame 364 of 1814
# Processed frame 365 of 1814
# Processed frame 366 of 1814
# Processed frame 367 of 1814
# Processed frame 368 of 1814
# Processed frame 369 of 1814
# Processed frame 370 of 1814
# Processed frame 371 of 1814
# Processed frame 372 of 1814
# Processed frame 373 of 1814
# Processed frame 374 of 1814
# Processed frame 375 of 1814
# Processed frame 376 of 1814
# Processed frame 377 of 1814
# Processed frame 378 of 1814
# Processed frame 379 of 1814
# Processed frame 380 of 1814
# Processed frame 381 of 1814
# Processed frame 382 of 1814
# Processed frame 383 of 1814
# Processed frame 384 of 1814
# Processed frame 385 of 1814
# Processed frame 386 of 1814
# Processed frame 387 of 1814
# Processed frame 388 of 1814
# Processed frame 389 of 1814
# Processed frame 390 of 1814
# Processed frame 391 of 1814
# Processed frame 392 of 1814
# Processed frame 393 of 1814
# Processed frame 394 of 1814
# Processed frame 395 of 1814
# Processed frame 396 of 1814
# Processed frame 397 of 1814
# Processed frame 398 of 1814
# Processed frame 399 of 1814
# Processed frame 400 of 1814
# Processed frame 401 of 1814
# Processed frame 402 of 1814
# Processed frame 403 of 1814
# Processed frame 404 of 1814
# Processed frame 405 of 1814
# Processed frame 406 of 1814
# Processed frame 407 of 1814
# Processed frame 408 of 1814
# Processed frame 409 of 1814
# Processed frame 410 of 1814
# Processed frame 411 of 1814
# Processed frame 412 of 1814
# Processed frame 413 of 1814
# Processed frame 414 of 1814
# Processed frame 415 of 1814
# Processed frame 416 of 1814
# Processed frame 417 of 1814
# Processed frame 418 of 1814
# Processed frame 419 of 1814
# Processed frame 420 of 1814
# Processed frame 421 of 1814
# Processed frame 422 of 1814
# Processed frame 423 of 1814
# Processed frame 424 of 1814
# Processed frame 425 of 1814
# Processed frame 426 of 1814
# Processed frame 427 of 1814
# Processed frame 428 of 1814
# Processed frame 429 of 1814
# Processed frame 430 of 1814
# Processed frame 431 of 1814
# Processed frame 432 of 1814
# Processed frame 433 of 1814
# Processed frame 434 of 1814
# Processed frame 435 of 1814
# Processed frame 436 of 1814
# Processed frame 437 of 1814
# Processed frame 438 of 1814
# Processed frame 439 of 1814
# Processed frame 440 of 1814
# Processed frame 441 of 1814
# Processed frame 442 of 1814
# Processed frame 443 of 1814
# Processed frame 444 of 1814
# Processed frame 445 of 1814
# Processed frame 446 of 1814
# Processed frame 447 of 1814
# Processed frame 448 of 1814
# Processed frame 449 of 1814
# Processed frame 450 of 1814
# Processed frame 451 of 1814
# Processed frame 452 of 1814
# Processed frame 453 of 1814
# Processed frame 454 of 1814
# Processed frame 455 of 1814
# Processed frame 456 of 1814
# Processed frame 457 of 1814
# Processed frame 458 of 1814
# Processed frame 459 of 1814
# Processed frame 460 of 1814
# Processed frame 461 of 1814
# Processed frame 462 of 1814
# Processed frame 463 of 1814
# Processed frame 464 of 1814
# Processed frame 465 of 1814
# Processed frame 466 of 1814
# Processed frame 467 of 1814
# Processed frame 468 of 1814
# Processed frame 469 of 1814
# Processed frame 470 of 1814
# Processed frame 471 of 1814
# Processed frame 472 of 1814
# Processed frame 473 of 1814
# Processed frame 474 of 1814
# Processed frame 475 of 1814
# Processed frame 476 of 1814
# Processed frame 477 of 1814
# Processed frame 478 of 1814
# Processed frame 479 of 1814
# Processed frame 480 of 1814
# Processed frame 481 of 1814
# Processed frame 482 of 1814
# Processed frame 483 of 1814
# Processed frame 484 of 1814
# Processed frame 485 of 1814
# Processed frame 486 of 1814
# Processed frame 487 of 1814
# Processed frame 488 of 1814
# Processed frame 489 of 1814
# Processed frame 490 of 1814
# Processed frame 491 of 1814
# Processed frame 492 of 1814
# Processed frame 493 of 1814
# Processed frame 494 of 1814
# Processed frame 495 of 1814
# Processed frame 496 of 1814
# Processed frame 497 of 1814
# Processed frame 498 of 1814
# Processed frame 499 of 1814
# Processed frame 500 of 1814
# Processed frame 501 of 1814
# Processed frame 502 of 1814
# Processed frame 503 of 1814
# Processed frame 504 of 1814
# Processed frame 505 of 1814
# Processed frame 506 of 1814
# Processed frame 507 of 1814
# Processed frame 508 of 1814
# Processed frame 509 of 1814
# Processed frame 510 of 1814
# Processed frame 511 of 1814
# Processed frame 512 of 1814
# Processed frame 513 of 1814
# Processed frame 514 of 1814
# Processed frame 515 of 1814
# Processed frame 516 of 1814
# Processed frame 517 of 1814
# Processed frame 518 of 1814
# Processed frame 519 of 1814
# Processed frame 520 of 1814
# Processed frame 521 of 1814
# Processed frame 522 of 1814
# Processed frame 523 of 1814
# Processed frame 524 of 1814
# Processed frame 525 of 1814
# Processed frame 526 of 1814
# Processed frame 527 of 1814
# Processed frame 528 of 1814
# Processed frame 529 of 1814
# Processed frame 530 of 1814
# Processed frame 531 of 1814
# Processed frame 532 of 1814
# Processed frame 533 of 1814
# Processed frame 534 of 1814
# Processed frame 535 of 1814
# Processed frame 536 of 1814
# Processed frame 537 of 1814
# Processed frame 538 of 1814
# Processed frame 539 of 1814
# Processed frame 540 of 1814
# Processed frame 541 of 1814
# Processed frame 542 of 1814
# Processed frame 543 of 1814
# Processed frame 544 of 1814
# Processed frame 545 of 1814
# Processed frame 546 of 1814
# Processed frame 547 of 1814
# Processed frame 548 of 1814
# Processed frame 549 of 1814
# Processed frame 550 of 1814
# Processed frame 551 of 1814
# Processed frame 552 of 1814
# Processed frame 553 of 1814
# Processed frame 554 of 1814
# Processed frame 555 of 1814
# Processed frame 556 of 1814
# Processed frame 557 of 1814
# Processed frame 558 of 1814
# Processed frame 559 of 1814
# Processed frame 560 of 1814
# Processed frame 561 of 1814
# Processed frame 562 of 1814
# Processed frame 563 of 1814
# Processed frame 564 of 1814
# Processed frame 565 of 1814
# Processed frame 566 of 1814
# Processed frame 567 of 1814
# Processed frame 568 of 1814
# Processed frame 569 of 1814
# Processed frame 570 of 1814
# Processed frame 571 of 1814
# Processed frame 572 of 1814
# Processed frame 573 of 1814
# Processed frame 574 of 1814
# Processed frame 575 of 1814
# Processed frame 576 of 1814
# Processed frame 577 of 1814
# Processed frame 578 of 1814
# Processed frame 579 of 1814
# Processed frame 580 of 1814
# Processed frame 581 of 1814
# Processed frame 582 of 1814
# Processed frame 583 of 1814
# Processed frame 584 of 1814
# Processed frame 585 of 1814
# Processed frame 586 of 1814
# Processed frame 587 of 1814
# Processed frame 588 of 1814
# Processed frame 589 of 1814
# Processed frame 590 of 1814
# Processed frame 591 of 1814
# Processed frame 592 of 1814
# Processed frame 593 of 1814
# Processed frame 594 of 1814
# Processed frame 595 of 1814
# Processed frame 596 of 1814
# Processed frame 597 of 1814
# Processed frame 598 of 1814
# Processed frame 599 of 1814
# Processed frame 600 of 1814
# Processed frame 601 of 1814
# Processed frame 602 of 1814
# Processed frame 603 of 1814
# Processed frame 604 of 1814
# Processed frame 605 of 1814
# Processed frame 606 of 1814
# Processed frame 607 of 1814
# Processed frame 608 of 1814
# Processed frame 609 of 1814
# Processed frame 610 of 1814
# Processed frame 611 of 1814
# Processed frame 612 of 1814
# Processed frame 613 of 1814
# Processed frame 614 of 1814
# Processed frame 615 of 1814
# Processed frame 616 of 1814
# Processed frame 617 of 1814
# Processed frame 618 of 1814
# Processed frame 619 of 1814
# Processed frame 620 of 1814
# Processed frame 621 of 1814
# Processed frame 622 of 1814
# Processed frame 623 of 1814
# Processed frame 624 of 1814
# Processed frame 625 of 1814
# Processed frame 626 of 1814
# Processed frame 627 of 1814
# Processed frame 628 of 1814
# Processed frame 629 of 1814
# Processed frame 630 of 1814
# Processed frame 631 of 1814
# Processed frame 632 of 1814
# Processed frame 633 of 1814
# Processed frame 634 of 1814
# Processed frame 635 of 1814
# Processed frame 636 of 1814
# Processed frame 637 of 1814
# Processed frame 638 of 1814
# Processed frame 639 of 1814
# Processed frame 640 of 1814
# Processed frame 641 of 1814
# Processed frame 642 of 1814
# Processed frame 643 of 1814
# Processed frame 644 of 1814
# Processed frame 645 of 1814
# Processed frame 646 of 1814
# Processed frame 647 of 1814
# Processed frame 648 of 1814
# Processed frame 649 of 1814
# Processed frame 650 of 1814
# Processed frame 651 of 1814
# Processed frame 652 of 1814
# Processed frame 653 of 1814
# Processed frame 654 of 1814
# Processed frame 655 of 1814
# Processed frame 656 of 1814
# Processed frame 657 of 1814
# Processed frame 658 of 1814
# Processed frame 659 of 1814
# Processed frame 660 of 1814
# Processed frame 661 of 1814
# Processed frame 662 of 1814
# Processed frame 663 of 1814
# Processed frame 664 of 1814
# Processed frame 665 of 1814
# Processed frame 666 of 1814
# Processed frame 667 of 1814
# Processed frame 668 of 1814
# Processed frame 669 of 1814
# Processed frame 670 of 1814
# Processed frame 671 of 1814
# Processed frame 672 of 1814
# Processed frame 673 of 1814
# Processed frame 674 of 1814
# Processed frame 675 of 1814
# Processed frame 676 of 1814
# Processed frame 677 of 1814
# Processed frame 678 of 1814
# Processed frame 679 of 1814
# Processed frame 680 of 1814
# Processed frame 681 of 1814
# Processed frame 682 of 1814
# Processed frame 683 of 1814
# Processed frame 684 of 1814
# Processed frame 685 of 1814
# Processed frame 686 of 1814
# Processed frame 687 of 1814
# Processed frame 688 of 1814
# Processed frame 689 of 1814
# Processed frame 690 of 1814
# Processed frame 691 of 1814
# Processed frame 692 of 1814
# Processed frame 693 of 1814
# Processed frame 694 of 1814
# Processed frame 695 of 1814
# Processed frame 696 of 1814
# Processed frame 697 of 1814
# Processed frame 698 of 1814
# Processed frame 699 of 1814
# Processed frame 700 of 1814
# Processed frame 701 of 1814
# Processed frame 702 of 1814
# Processed frame 703 of 1814
# Processed frame 704 of 1814
# Processed frame 705 of 1814
# Processed frame 706 of 1814
# Processed frame 707 of 1814
# Processed frame 708 of 1814
# Processed frame 709 of 1814
# Processed frame 710 of 1814
# Processed frame 711 of 1814
# Processed frame 712 of 1814
# Processed frame 713 of 1814
# Processed frame 714 of 1814
# Processed frame 715 of 1814
# Processed frame 716 of 1814
# Processed frame 717 of 1814
# Processed frame 718 of 1814
# Processed frame 719 of 1814
# Processed frame 720 of 1814
# Processed frame 721 of 1814
# Processed frame 722 of 1814
# Processed frame 723 of 1814
# Processed frame 724 of 1814
# Processed frame 725 of 1814
# Processed frame 726 of 1814
# Processed frame 727 of 1814
# Processed frame 728 of 1814
# Processed frame 729 of 1814
# Processed frame 730 of 1814
# Processed frame 731 of 1814
# Processed frame 732 of 1814
# Processed frame 733 of 1814
# Processed frame 734 of 1814
# Processed frame 735 of 1814
# Processed frame 736 of 1814
# Processed frame 737 of 1814
# Processed frame 738 of 1814
# Processed frame 739 of 1814
# Processed frame 740 of 1814
# Processed frame 741 of 1814
# Processed frame 742 of 1814
# Processed frame 743 of 1814
# Processed frame 744 of 1814
# Processed frame 745 of 1814
# Processed frame 746 of 1814
# Processed frame 747 of 1814
# Processed frame 748 of 1814
# Processed frame 749 of 1814
# Processed frame 750 of 1814
# Processed frame 751 of 1814
# Processed frame 752 of 1814
# Processed frame 753 of 1814
# Processed frame 754 of 1814
# Processed frame 755 of 1814
# Processed frame 756 of 1814
# Processed frame 757 of 1814
# Processed frame 758 of 1814
# Processed frame 759 of 1814
# Processed frame 760 of 1814
# Processed frame 761 of 1814
# Processed frame 762 of 1814
# Processed frame 763 of 1814
# Processed frame 764 of 1814
# Processed frame 765 of 1814
# Processed frame 766 of 1814
# Processed frame 767 of 1814
# Processed frame 768 of 1814
# Processed frame 769 of 1814
# Processed frame 770 of 1814
# Processed frame 771 of 1814
# Processed frame 772 of 1814
# Processed frame 773 of 1814
# Processed frame 774 of 1814
# Processed frame 775 of 1814
# Processed frame 776 of 1814
# Processed frame 777 of 1814
# Processed frame 778 of 1814
# Processed frame 779 of 1814
# Processed frame 780 of 1814
# Processed frame 781 of 1814
# Processed frame 782 of 1814
# Processed frame 783 of 1814
# Processed frame 784 of 1814
# Processed frame 785 of 1814
# Processed frame 786 of 1814
# Processed frame 787 of 1814
# Processed frame 788 of 1814
# Processed frame 789 of 1814
# Processed frame 790 of 1814
# Processed frame 791 of 1814
# Processed frame 792 of 1814
# Processed frame 793 of 1814
# Processed frame 794 of 1814
# Processed frame 795 of 1814
# Processed frame 796 of 1814
# Processed frame 797 of 1814
# Processed frame 798 of 1814
# Processed frame 799 of 1814
# Processed frame 800 of 1814
# Processed frame 801 of 1814
# Processed frame 802 of 1814
# Processed frame 803 of 1814
# Processed frame 804 of 1814
# Processed frame 805 of 1814
# Processed frame 806 of 1814
# Processed frame 807 of 1814
# Processed frame 808 of 1814
# Processed frame 809 of 1814
# Processed frame 810 of 1814
# Processed frame 811 of 1814
# Processed frame 812 of 1814
# Processed frame 813 of 1814
# Processed frame 814 of 1814
# Processed frame 815 of 1814
# Processed frame 816 of 1814
# Processed frame 817 of 1814
# Processed frame 818 of 1814
# Processed frame 819 of 1814
# Processed frame 820 of 1814
# Processed frame 821 of 1814
# Processed frame 822 of 1814
# Processed frame 823 of 1814
# Processed frame 824 of 1814
# Processed frame 825 of 1814
# Processed frame 826 of 1814
# Processed frame 827 of 1814
# Processed frame 828 of 1814
# Processed frame 829 of 1814
# Processed frame 830 of 1814
# Processed frame 831 of 1814
# Processed frame 832 of 1814
# Processed frame 833 of 1814
# Processed frame 834 of 1814
# Processed frame 835 of 1814
# Processed frame 836 of 1814
# Processed frame 837 of 1814
# Processed frame 838 of 1814
# Processed frame 839 of 1814
# Processed frame 840 of 1814
# Processed frame 841 of 1814
# Processed frame 842 of 1814
# Processed frame 843 of 1814
# Processed frame 844 of 1814
# Processed frame 845 of 1814
# Processed frame 846 of 1814
# Processed frame 847 of 1814
# Processed frame 848 of 1814
# Processed frame 849 of 1814
# Processed frame 850 of 1814
# Processed frame 851 of 1814
# Processed frame 852 of 1814
# Processed frame 853 of 1814
# Processed frame 854 of 1814
# Processed frame 855 of 1814
# Processed frame 856 of 1814
# Processed frame 857 of 1814
# Processed frame 858 of 1814
# Processed frame 859 of 1814
# Processed frame 860 of 1814
# Processed frame 861 of 1814
# Processed frame 862 of 1814
# Processed frame 863 of 1814
# Processed frame 864 of 1814
# Processed frame 865 of 1814
# Processed frame 866 of 1814
# Processed frame 867 of 1814
# Processed frame 868 of 1814
# Processed frame 869 of 1814
# Processed frame 870 of 1814
# Processed frame 871 of 1814
# Processed frame 872 of 1814
# Processed frame 873 of 1814
# Processed frame 874 of 1814
# Processed frame 875 of 1814
# Processed frame 876 of 1814
# Processed frame 877 of 1814
# Processed frame 878 of 1814
# Processed frame 879 of 1814
# Processed frame 880 of 1814
# Processed frame 881 of 1814
# Processed frame 882 of 1814
# Processed frame 883 of 1814
# Processed frame 884 of 1814
# Processed frame 885 of 1814
# Processed frame 886 of 1814
# Processed frame 887 of 1814
# Processed frame 888 of 1814
# Processed frame 889 of 1814
# Processed frame 890 of 1814
# Processed frame 891 of 1814
# Processed frame 892 of 1814
# Processed frame 893 of 1814
# Processed frame 894 of 1814
# Processed frame 895 of 1814
# Processed frame 896 of 1814
# Processed frame 897 of 1814
# Processed frame 898 of 1814
# Processed frame 899 of 1814
# Processed frame 900 of 1814
# Processed frame 901 of 1814
# Processed frame 902 of 1814
# Processed frame 903 of 1814
# Processed frame 904 of 1814
# Processed frame 905 of 1814
# Processed frame 906 of 1814
# Processed frame 907 of 1814
# Processed frame 908 of 1814
# Processed frame 909 of 1814
# Processed frame 910 of 1814
# Processed frame 911 of 1814
# Processed frame 912 of 1814
# Processed frame 913 of 1814
# Processed frame 914 of 1814
# Processed frame 915 of 1814
# Processed frame 916 of 1814
# Processed frame 917 of 1814
# Processed frame 918 of 1814
# Processed frame 919 of 1814
# Processed frame 920 of 1814
# Processed frame 921 of 1814
# Processed frame 922 of 1814
# Processed frame 923 of 1814
# Processed frame 924 of 1814
# Processed frame 925 of 1814
# Processed frame 926 of 1814
# Processed frame 927 of 1814
# Processed frame 928 of 1814
# Processed frame 929 of 1814
# Processed frame 930 of 1814
# Processed frame 931 of 1814
# Processed frame 932 of 1814
# Processed frame 933 of 1814
# Processed frame 934 of 1814
# Processed frame 935 of 1814
# Processed frame 936 of 1814
# Processed frame 937 of 1814
# Processed frame 938 of 1814
# Processed frame 939 of 1814
# Processed frame 940 of 1814
# Processed frame 941 of 1814
# Processed frame 942 of 1814
# Processed frame 943 of 1814
# Processed frame 944 of 1814
# Processed frame 945 of 1814
# Processed frame 946 of 1814
# Processed frame 947 of 1814
# Processed frame 948 of 1814
# Processed frame 949 of 1814
# Processed frame 950 of 1814
# Processed frame 951 of 1814
# Processed frame 952 of 1814
# Processed frame 953 of 1814
# Processed frame 954 of 1814
# Processed frame 955 of 1814
# Processed frame 956 of 1814
# Processed frame 957 of 1814
# Processed frame 958 of 1814
# Processed frame 959 of 1814
# Processed frame 960 of 1814
# Processed frame 961 of 1814
# Processed frame 962 of 1814
# Processed frame 963 of 1814
# Processed frame 964 of 1814
# Processed frame 965 of 1814
# Processed frame 966 of 1814
# Processed frame 967 of 1814
# Processed frame 968 of 1814
# Processed frame 969 of 1814
# Processed frame 970 of 1814
# Processed frame 971 of 1814
# Processed frame 972 of 1814
# Processed frame 973 of 1814
# Processed frame 974 of 1814
# Processed frame 975 of 1814
# Processed frame 976 of 1814
# Processed frame 977 of 1814
# Processed frame 978 of 1814
# Processed frame 979 of 1814
# Processed frame 980 of 1814
# Processed frame 981 of 1814
# Processed frame 982 of 1814
# Processed frame 983 of 1814
# Processed frame 984 of 1814
# Processed frame 985 of 1814
# Processed frame 986 of 1814
# Processed frame 987 of 1814
# Processed frame 988 of 1814
# Processed frame 989 of 1814
# Processed frame 990 of 1814
# Processed frame 991 of 1814
# Processed frame 992 of 1814
# Processed frame 993 of 1814
# Processed frame 994 of 1814
# Processed frame 995 of 1814
# Processed frame 996 of 1814
# Processed frame 997 of 1814
# Processed frame 998 of 1814
# Processed frame 999 of 1814
# Processed frame 1000 of 1814
# Processed frame 1001 of 1814
# Processed frame 1002 of 1814
# Processed frame 1003 of 1814
# Processed frame 1004 of 1814
# Processed frame 1005 of 1814
# Processed frame 1006 of 1814
# Processed frame 1007 of 1814
# Processed frame 1008 of 1814
# Processed frame 1009 of 1814
# Processed frame 1010 of 1814
# Processed frame 1011 of 1814
# Processed frame 1012 of 1814
# Processed frame 1013 of 1814
# Processed frame 1014 of 1814
# Processed frame 1015 of 1814
# Processed frame 1016 of 1814
# Processed frame 1017 of 1814
# Processed frame 1018 of 1814
# Processed frame 1019 of 1814
# Processed frame 1020 of 1814
# Processed frame 1021 of 1814
# Processed frame 1022 of 1814
# Processed frame 1023 of 1814
# Processed frame 1024 of 1814
# Processed frame 1025 of 1814
# Processed frame 1026 of 1814
# Processed frame 1027 of 1814
# Processed frame 1028 of 1814
# Processed frame 1029 of 1814
# Processed frame 1030 of 1814
# Processed frame 1031 of 1814
# Processed frame 1032 of 1814
# Processed frame 1033 of 1814
# Processed frame 1034 of 1814
# Processed frame 1035 of 1814
# Processed frame 1036 of 1814
# Processed frame 1037 of 1814
# Processed frame 1038 of 1814
# Processed frame 1039 of 1814
# Processed frame 1040 of 1814
# Processed frame 1041 of 1814
# Processed frame 1042 of 1814
# Processed frame 1043 of 1814
# Processed frame 1044 of 1814
# Processed frame 1045 of 1814
# Processed frame 1046 of 1814
# Processed frame 1047 of 1814
# Processed frame 1048 of 1814
# Processed frame 1049 of 1814
# Processed frame 1050 of 1814
# Processed frame 1051 of 1814
# Processed frame 1052 of 1814
# Processed frame 1053 of 1814
# Processed frame 1054 of 1814
# Processed frame 1055 of 1814
# Processed frame 1056 of 1814
# Processed frame 1057 of 1814
# Processed frame 1058 of 1814
# Processed frame 1059 of 1814
# Processed frame 1060 of 1814
# Processed frame 1061 of 1814
# Processed frame 1062 of 1814
# Processed frame 1063 of 1814
# Processed frame 1064 of 1814
# Processed frame 1065 of 1814
# Processed frame 1066 of 1814
# Processed frame 1067 of 1814
# Processed frame 1068 of 1814
# Processed frame 1069 of 1814
# Processed frame 1070 of 1814
# Processed frame 1071 of 1814
# Processed frame 1072 of 1814
# Processed frame 1073 of 1814
# Processed frame 1074 of 1814
# Processed frame 1075 of 1814
# Processed frame 1076 of 1814
# Processed frame 1077 of 1814
# Processed frame 1078 of 1814
# Processed frame 1079 of 1814
# Processed frame 1080 of 1814
# Processed frame 1081 of 1814
# Processed frame 1082 of 1814
# Processed frame 1083 of 1814
# Processed frame 1084 of 1814
# Processed frame 1085 of 1814
# Processed frame 1086 of 1814
# Processed frame 1087 of 1814
# Processed frame 1088 of 1814
# Processed frame 1089 of 1814
# Processed frame 1090 of 1814
# Processed frame 1091 of 1814
# Processed frame 1092 of 1814
# Processed frame 1093 of 1814
# Processed frame 1094 of 1814
# Processed frame 1095 of 1814
# Processed frame 1096 of 1814
# Processed frame 1097 of 1814
# Processed frame 1098 of 1814
# Processed frame 1099 of 1814
# Processed frame 1100 of 1814
# Processed frame 1101 of 1814
# Processed frame 1102 of 1814
# Processed frame 1103 of 1814
# Processed frame 1104 of 1814
# Processed frame 1105 of 1814
# Processed frame 1106 of 1814
# Processed frame 1107 of 1814
# Processed frame 1108 of 1814
# Processed frame 1109 of 1814
# Processed frame 1110 of 1814
# Processed frame 1111 of 1814
# Processed frame 1112 of 1814
# Processed frame 1113 of 1814
# Processed frame 1114 of 1814
# Processed frame 1115 of 1814
# Processed frame 1116 of 1814
# Processed frame 1117 of 1814
# Processed frame 1118 of 1814
# Processed frame 1119 of 1814
# Processed frame 1120 of 1814
# Processed frame 1121 of 1814
# Processed frame 1122 of 1814
# Processed frame 1123 of 1814
# Processed frame 1124 of 1814
# Processed frame 1125 of 1814
# Processed frame 1126 of 1814
# Processed frame 1127 of 1814
# Processed frame 1128 of 1814
# Processed frame 1129 of 1814
# Processed frame 1130 of 1814
# Processed frame 1131 of 1814
# Processed frame 1132 of 1814
# Processed frame 1133 of 1814
# Processed frame 1134 of 1814
# Processed frame 1135 of 1814
# Processed frame 1136 of 1814
# Processed frame 1137 of 1814
# Processed frame 1138 of 1814
# Processed frame 1139 of 1814
# Processed frame 1140 of 1814
# Processed frame 1141 of 1814
# Processed frame 1142 of 1814
# Processed frame 1143 of 1814
# Processed frame 1144 of 1814
# Processed frame 1145 of 1814
# Processed frame 1146 of 1814
# Processed frame 1147 of 1814
# Processed frame 1148 of 1814
# Processed frame 1149 of 1814
# Processed frame 1150 of 1814
# Processed frame 1151 of 1814
# Processed frame 1152 of 1814
# Processed frame 1153 of 1814
# Processed frame 1154 of 1814
# Processed frame 1155 of 1814
# Processed frame 1156 of 1814
# Processed frame 1157 of 1814
# Processed frame 1158 of 1814
# Processed frame 1159 of 1814
# Processed frame 1160 of 1814
# Processed frame 1161 of 1814
# Processed frame 1162 of 1814
# Processed frame 1163 of 1814
# Processed frame 1164 of 1814
# Processed frame 1165 of 1814
# Processed frame 1166 of 1814
# Processed frame 1167 of 1814
# Processed frame 1168 of 1814
# Processed frame 1169 of 1814
# Processed frame 1170 of 1814
# Processed frame 1171 of 1814
# Processed frame 1172 of 1814
# Processed frame 1173 of 1814
# Processed frame 1174 of 1814
# Processed frame 1175 of 1814
# Processed frame 1176 of 1814
# Processed frame 1177 of 1814
# Processed frame 1178 of 1814
# Processed frame 1179 of 1814
# Processed frame 1180 of 1814
# Processed frame 1181 of 1814
# Processed frame 1182 of 1814
# Processed frame 1183 of 1814
# Processed frame 1184 of 1814
# Processed frame 1185 of 1814
# Processed frame 1186 of 1814
# Processed frame 1187 of 1814
# Processed frame 1188 of 1814
# Processed frame 1189 of 1814
# Processed frame 1190 of 1814
# Processed frame 1191 of 1814
# Processed frame 1192 of 1814
# Processed frame 1193 of 1814
# Processed frame 1194 of 1814
# Processed frame 1195 of 1814
# Processed frame 1196 of 1814
# Processed frame 1197 of 1814
# Processed frame 1198 of 1814
# Processed frame 1199 of 1814
# Processed frame 1200 of 1814
# Processed frame 1201 of 1814
# Processed frame 1202 of 1814
# Processed frame 1203 of 1814
# Processed frame 1204 of 1814
# Processed frame 1205 of 1814
# Processed frame 1206 of 1814
# Processed frame 1207 of 1814
# Processed frame 1208 of 1814
# Processed frame 1209 of 1814
# Processed frame 1210 of 1814
# Processed frame 1211 of 1814
# Processed frame 1212 of 1814
# Processed frame 1213 of 1814
# Processed frame 1214 of 1814
# Processed frame 1215 of 1814
# Processed frame 1216 of 1814
# Processed frame 1217 of 1814
# Processed frame 1218 of 1814
# Processed frame 1219 of 1814
# Processed frame 1220 of 1814
# Processed frame 1221 of 1814
# Processed frame 1222 of 1814
# Processed frame 1223 of 1814
# Processed frame 1224 of 1814
# Processed frame 1225 of 1814
# Processed frame 1226 of 1814
# Processed frame 1227 of 1814
# Processed frame 1228 of 1814
# Processed frame 1229 of 1814
# Processed frame 1230 of 1814
# Processed frame 1231 of 1814
# Processed frame 1232 of 1814
# Processed frame 1233 of 1814
# Processed frame 1234 of 1814
# Processed frame 1235 of 1814
# Processed frame 1236 of 1814
# Processed frame 1237 of 1814
# Processed frame 1238 of 1814
# Processed frame 1239 of 1814
# Processed frame 1240 of 1814
# Processed frame 1241 of 1814
# Processed frame 1242 of 1814
# Processed frame 1243 of 1814
# Processed frame 1244 of 1814
# Processed frame 1245 of 1814
# Processed frame 1246 of 1814
# Processed frame 1247 of 1814
# Processed frame 1248 of 1814
# Processed frame 1249 of 1814
# Processed frame 1250 of 1814
# Processed frame 1251 of 1814
# Processed frame 1252 of 1814
# Processed frame 1253 of 1814
# Processed frame 1254 of 1814
# Processed frame 1255 of 1814
# Processed frame 1256 of 1814
# Processed frame 1257 of 1814
# Processed frame 1258 of 1814
# Processed frame 1259 of 1814
# Processed frame 1260 of 1814
# Processed frame 1261 of 1814
# Processed frame 1262 of 1814
# Processed frame 1263 of 1814
# Processed frame 1264 of 1814
# Processed frame 1265 of 1814
# Processed frame 1266 of 1814
# Processed frame 1267 of 1814
# Processed frame 1268 of 1814
# Processed frame 1269 of 1814
# Processed frame 1270 of 1814
# Processed frame 1271 of 1814
# Processed frame 1272 of 1814
# Processed frame 1273 of 1814
# Processed frame 1274 of 1814
# Processed frame 1275 of 1814
# Processed frame 1276 of 1814
# Processed frame 1277 of 1814
# Processed frame 1278 of 1814
# Processed frame 1279 of 1814
# Processed frame 1280 of 1814
# Processed frame 1281 of 1814
# Processed frame 1282 of 1814
# Processed frame 1283 of 1814
# Processed frame 1284 of 1814
# Processed frame 1285 of 1814
# Processed frame 1286 of 1814
# Processed frame 1287 of 1814
# Processed frame 1288 of 1814
# Processed frame 1289 of 1814
# Processed frame 1290 of 1814
# Processed frame 1291 of 1814
# Processed frame 1292 of 1814
# Processed frame 1293 of 1814
# Processed frame 1294 of 1814
# Processed frame 1295 of 1814
# Processed frame 1296 of 1814
# Processed frame 1297 of 1814
# Processed frame 1298 of 1814
# Processed frame 1299 of 1814
# Processed frame 1300 of 1814
# Processed frame 1301 of 1814
# Processed frame 1302 of 1814
# Processed frame 1303 of 1814
# Processed frame 1304 of 1814
# Processed frame 1305 of 1814
# Processed frame 1306 of 1814
# Processed frame 1307 of 1814
# Processed frame 1308 of 1814
# Processed frame 1309 of 1814
# Processed frame 1310 of 1814
# Processed frame 1311 of 1814
# Processed frame 1312 of 1814
# Processed frame 1313 of 1814
# Processed frame 1314 of 1814
# Processed frame 1315 of 1814
# Processed frame 1316 of 1814
# Processed frame 1317 of 1814
# Processed frame 1318 of 1814
# Processed frame 1319 of 1814
# Processed frame 1320 of 1814
# Processed frame 1321 of 1814
# Processed frame 1322 of 1814
# Processed frame 1323 of 1814
# Processed frame 1324 of 1814
# Processed frame 1325 of 1814
# Processed frame 1326 of 1814
# Processed frame 1327 of 1814
# Processed frame 1328 of 1814
# Processed frame 1329 of 1814
# Processed frame 1330 of 1814
# Processed frame 1331 of 1814
# Processed frame 1332 of 1814
# Processed frame 1333 of 1814
# Processed frame 1334 of 1814
# Processed frame 1335 of 1814
# Processed frame 1336 of 1814
# Processed frame 1337 of 1814
# Processed frame 1338 of 1814
# Processed frame 1339 of 1814
# Processed frame 1340 of 1814
# Processed frame 1341 of 1814
# Processed frame 1342 of 1814
# Processed frame 1343 of 1814
# Processed frame 1344 of 1814
# Processed frame 1345 of 1814
# Processed frame 1346 of 1814
# Processed frame 1347 of 1814
# Processed frame 1348 of 1814
# Processed frame 1349 of 1814
# Processed frame 1350 of 1814
# Processed frame 1351 of 1814
# Processed frame 1352 of 1814
# Processed frame 1353 of 1814
# Processed frame 1354 of 1814
# Processed frame 1355 of 1814
# Processed frame 1356 of 1814
# Processed frame 1357 of 1814
# Processed frame 1358 of 1814
# Processed frame 1359 of 1814
# Processed frame 1360 of 1814
# Processed frame 1361 of 1814
# Processed frame 1362 of 1814
# Processed frame 1363 of 1814
# Processed frame 1364 of 1814
# Processed frame 1365 of 1814
# Processed frame 1366 of 1814
# Processed frame 1367 of 1814
# Processed frame 1368 of 1814
# Processed frame 1369 of 1814
# Processed frame 1370 of 1814
# Processed frame 1371 of 1814
# Processed frame 1372 of 1814
# Processed frame 1373 of 1814
# Processed frame 1374 of 1814
# Processed frame 1375 of 1814
# Processed frame 1376 of 1814
# Processed frame 1377 of 1814
# Processed frame 1378 of 1814
# Processed frame 1379 of 1814
# Processed frame 1380 of 1814
# Processed frame 1381 of 1814
# Processed frame 1382 of 1814
# Processed frame 1383 of 1814
# Processed frame 1384 of 1814
# Processed frame 1385 of 1814
# Processed frame 1386 of 1814
# Processed frame 1387 of 1814
# Processed frame 1388 of 1814
# Processed frame 1389 of 1814
# Processed frame 1390 of 1814
# Processed frame 1391 of 1814
# Processed frame 1392 of 1814
# Processed frame 1393 of 1814
# Processed frame 1394 of 1814
# Processed frame 1395 of 1814
# Processed frame 1396 of 1814
# Processed frame 1397 of 1814
# Processed frame 1398 of 1814
# Processed frame 1399 of 1814
# Processed frame 1400 of 1814
# Processed frame 1401 of 1814
# Processed frame 1402 of 1814
# Processed frame 1403 of 1814
# Processed frame 1404 of 1814
# Processed frame 1405 of 1814
# Processed frame 1406 of 1814
# Processed frame 1407 of 1814
# Processed frame 1408 of 1814
# Processed frame 1409 of 1814
# Processed frame 1410 of 1814
# Processed frame 1411 of 1814
# Processed frame 1412 of 1814
# Processed frame 1413 of 1814
# Processed frame 1414 of 1814
# Processed frame 1415 of 1814
# Processed frame 1416 of 1814
# Processed frame 1417 of 1814
# Processed frame 1418 of 1814
# Processed frame 1419 of 1814
# Processed frame 1420 of 1814
# Processed frame 1421 of 1814
# Processed frame 1422 of 1814
# Processed frame 1423 of 1814
# Processed frame 1424 of 1814
# Processed frame 1425 of 1814
# Processed frame 1426 of 1814
# Processed frame 1427 of 1814
# Processed frame 1428 of 1814
# Processed frame 1429 of 1814
# Processed frame 1430 of 1814
# Processed frame 1431 of 1814
# Processed frame 1432 of 1814
# Processed frame 1433 of 1814
# Processed frame 1434 of 1814
# Processed frame 1435 of 1814
# Processed frame 1436 of 1814
# Processed frame 1437 of 1814
# Processed frame 1438 of 1814
# Processed frame 1439 of 1814
# Processed frame 1440 of 1814
# Processed frame 1441 of 1814
# Processed frame 1442 of 1814
# Processed frame 1443 of 1814
# Processed frame 1444 of 1814
# Processed frame 1445 of 1814
# Processed frame 1446 of 1814
# Processed frame 1447 of 1814
# Processed frame 1448 of 1814
# Processed frame 1449 of 1814
# Processed frame 1450 of 1814
# Processed frame 1451 of 1814
# Processed frame 1452 of 1814
# Processed frame 1453 of 1814
# Processed frame 1454 of 1814
# Processed frame 1455 of 1814
# Processed frame 1456 of 1814
# Processed frame 1457 of 1814
# Processed frame 1458 of 1814
# Processed frame 1459 of 1814
# Processed frame 1460 of 1814
# Processed frame 1461 of 1814
# Processed frame 1462 of 1814
# Processed frame 1463 of 1814
# Processed frame 1464 of 1814
# Processed frame 1465 of 1814
# Processed frame 1466 of 1814
# Processed frame 1467 of 1814
# Processed frame 1468 of 1814
# Processed frame 1469 of 1814
# Processed frame 1470 of 1814
# Processed frame 1471 of 1814
# Processed frame 1472 of 1814
# Processed frame 1473 of 1814
# Processed frame 1474 of 1814
# Processed frame 1475 of 1814
# Processed frame 1476 of 1814
# Processed frame 1477 of 1814
# Processed frame 1478 of 1814
# Processed frame 1479 of 1814
# Processed frame 1480 of 1814
# Processed frame 1481 of 1814
# Processed frame 1482 of 1814
# Processed frame 1483 of 1814
# Processed frame 1484 of 1814
# Processed frame 1485 of 1814
# Processed frame 1486 of 1814
# Processed frame 1487 of 1814
# Processed frame 1488 of 1814
# Processed frame 1489 of 1814
# Processed frame 1490 of 1814
# Processed frame 1491 of 1814
# Processed frame 1492 of 1814
# Processed frame 1493 of 1814
# Processed frame 1494 of 1814
# Processed frame 1495 of 1814
# Processed frame 1496 of 1814
# Processed frame 1497 of 1814
# Processed frame 1498 of 1814
# Processed frame 1499 of 1814
# Processed frame 1500 of 1814
# Processed frame 1501 of 1814
# Processed frame 1502 of 1814
# Processed frame 1503 of 1814
# Processed frame 1504 of 1814
# Processed frame 1505 of 1814
# Processed frame 1506 of 1814
# Processed frame 1507 of 1814
# Processed frame 1508 of 1814
# Processed frame 1509 of 1814
# Processed frame 1510 of 1814
# Processed frame 1511 of 1814
# Processed frame 1512 of 1814
# Processed frame 1513 of 1814
# Processed frame 1514 of 1814
# Processed frame 1515 of 1814
# Processed frame 1516 of 1814
# Processed frame 1517 of 1814
# Processed frame 1518 of 1814
# Processed frame 1519 of 1814
# Processed frame 1520 of 1814
# Processed frame 1521 of 1814
# Processed frame 1522 of 1814
# Processed frame 1523 of 1814
# Processed frame 1524 of 1814
# Processed frame 1525 of 1814
# Processed frame 1526 of 1814
# Processed frame 1527 of 1814
# Processed frame 1528 of 1814
# Processed frame 1529 of 1814
# Processed frame 1530 of 1814
# Processed frame 1531 of 1814
# Processed frame 1532 of 1814
# Processed frame 1533 of 1814
# Processed frame 1534 of 1814
# Processed frame 1535 of 1814
# Processed frame 1536 of 1814
# Processed frame 1537 of 1814
# Processed frame 1538 of 1814
# Processed frame 1539 of 1814
# Processed frame 1540 of 1814
# Processed frame 1541 of 1814
# Processed frame 1542 of 1814
# Processed frame 1543 of 1814
# Processed frame 1544 of 1814
# Processed frame 1545 of 1814
# Processed frame 1546 of 1814
# Processed frame 1547 of 1814
# Processed frame 1548 of 1814
# Processed frame 1549 of 1814
# Processed frame 1550 of 1814
# Processed frame 1551 of 1814
# Processed frame 1552 of 1814
# Processed frame 1553 of 1814
# Processed frame 1554 of 1814
# Processed frame 1555 of 1814
# Processed frame 1556 of 1814
# Processed frame 1557 of 1814
# Processed frame 1558 of 1814
# Processed frame 1559 of 1814
# Processed frame 1560 of 1814
# Processed frame 1561 of 1814
# Processed frame 1562 of 1814
# Processed frame 1563 of 1814
# Processed frame 1564 of 1814
# Processed frame 1565 of 1814
# Processed frame 1566 of 1814
# Processed frame 1567 of 1814
# Processed frame 1568 of 1814
# Processed frame 1569 of 1814
# Processed frame 1570 of 1814
# Processed frame 1571 of 1814
# Processed frame 1572 of 1814
# Processed frame 1573 of 1814
# Processed frame 1574 of 1814
# Processed frame 1575 of 1814
# Processed frame 1576 of 1814
# Processed frame 1577 of 1814
# Processed frame 1578 of 1814
# Processed frame 1579 of 1814
# Processed frame 1580 of 1814
# Processed frame 1581 of 1814
# Processed frame 1582 of 1814
# Processed frame 1583 of 1814
# Processed frame 1584 of 1814
# Processed frame 1585 of 1814
# Processed frame 1586 of 1814
# Processed frame 1587 of 1814
# Processed frame 1588 of 1814
# Processed frame 1589 of 1814
# Processed frame 1590 of 1814
# Processed frame 1591 of 1814
# Processed frame 1592 of 1814
# Processed frame 1593 of 1814
# Processed frame 1594 of 1814
# Processed frame 1595 of 1814
# Processed frame 1596 of 1814
# Processed frame 1597 of 1814
# Processed frame 1598 of 1814
# Processed frame 1599 of 1814
# Processed frame 1600 of 1814
# Processed frame 1601 of 1814
# Processed frame 1602 of 1814
# Processed frame 1603 of 1814
# Processed frame 1604 of 1814
# Processed frame 1605 of 1814
# Processed frame 1606 of 1814
# Processed frame 1607 of 1814
# Processed frame 1608 of 1814
# Processed frame 1609 of 1814
# Processed frame 1610 of 1814
# Processed frame 1611 of 1814
# Processed frame 1612 of 1814
# Processed frame 1613 of 1814
# Processed frame 1614 of 1814
# Processed frame 1615 of 1814
# Processed frame 1616 of 1814
# Processed frame 1617 of 1814
# Processed frame 1618 of 1814
# Processed frame 1619 of 1814
# Processed frame 1620 of 1814
# Processed frame 1621 of 1814
# Processed frame 1622 of 1814
# Processed frame 1623 of 1814
# Processed frame 1624 of 1814
# Processed frame 1625 of 1814
# Processed frame 1626 of 1814
# Processed frame 1627 of 1814
# Processed frame 1628 of 1814
# Processed frame 1629 of 1814
# Processed frame 1630 of 1814
# Processed frame 1631 of 1814
# Processed frame 1632 of 1814
# Processed frame 1633 of 1814
# Processed frame 1634 of 1814
# Processed frame 1635 of 1814
# Processed frame 1636 of 1814
# Processed frame 1637 of 1814
# Processed frame 1638 of 1814
# Processed frame 1639 of 1814
# Processed frame 1640 of 1814
# Processed frame 1641 of 1814
# Processed frame 1642 of 1814
# Processed frame 1643 of 1814
# Processed frame 1644 of 1814
# Processed frame 1645 of 1814
# Processed frame 1646 of 1814
# Processed frame 1647 of 1814
# Processed frame 1648 of 1814
# Processed frame 1649 of 1814
# Processed frame 1650 of 1814
# Processed frame 1651 of 1814
# Processed frame 1652 of 1814
# Processed frame 1653 of 1814
# Processed frame 1654 of 1814
# Processed frame 1655 of 1814
# Processed frame 1656 of 1814
# Processed frame 1657 of 1814
# Processed frame 1658 of 1814
# Processed frame 1659 of 1814
# Processed frame 1660 of 1814
# Processed frame 1661 of 1814
# Processed frame 1662 of 1814
# Processed frame 1663 of 1814
# Processed frame 1664 of 1814
# Processed frame 1665 of 1814
# Processed frame 1666 of 1814
# Processed frame 1667 of 1814
# Processed frame 1668 of 1814
# Processed frame 1669 of 1814
# Processed frame 1670 of 1814
# Processed frame 1671 of 1814
# Processed frame 1672 of 1814
# Processed frame 1673 of 1814
# Processed frame 1674 of 1814
# Processed frame 1675 of 1814
# Processed frame 1676 of 1814
# Processed frame 1677 of 1814
# Processed frame 1678 of 1814
# Processed frame 1679 of 1814
# Processed frame 1680 of 1814
# Processed frame 1681 of 1814
# Processed frame 1682 of 1814
# Processed frame 1683 of 1814
# Processed frame 1684 of 1814
# Processed frame 1685 of 1814
# Processed frame 1686 of 1814
# Processed frame 1687 of 1814
# Processed frame 1688 of 1814
# Processed frame 1689 of 1814
# Processed frame 1690 of 1814
# Processed frame 1691 of 1814
# Processed frame 1692 of 1814
# Processed frame 1693 of 1814
# Processed frame 1694 of 1814
# Processed frame 1695 of 1814
# Processed frame 1696 of 1814
# Processed frame 1697 of 1814
# Processed frame 1698 of 1814
# Processed frame 1699 of 1814
# Processed frame 1700 of 1814
# Processed frame 1701 of 1814
# Processed frame 1702 of 1814
# Processed frame 1703 of 1814
# Processed frame 1704 of 1814
# Processed frame 1705 of 1814
# Processed frame 1706 of 1814
# Processed frame 1707 of 1814
# Processed frame 1708 of 1814
# Processed frame 1709 of 1814
# Processed frame 1710 of 1814
# Processed frame 1711 of 1814
# Processed frame 1712 of 1814
# Processed frame 1713 of 1814
# Processed frame 1714 of 1814
# Processed frame 1715 of 1814
# Processed frame 1716 of 1814
# Processed frame 1717 of 1814
# Processed frame 1718 of 1814
# Processed frame 1719 of 1814
# Processed frame 1720 of 1814
# Processed frame 1721 of 1814
# Processed frame 1722 of 1814
# Processed frame 1723 of 1814
# Processed frame 1724 of 1814
# Processed frame 1725 of 1814
# Processed frame 1726 of 1814
# Processed frame 1727 of 1814
# Processed frame 1728 of 1814
# Processed frame 1729 of 1814
# Processed frame 1730 of 1814
# Processed frame 1731 of 1814
# Processed frame 1732 of 1814
# Processed frame 1733 of 1814
# Processed frame 1734 of 1814
# Processed frame 1735 of 1814
# Processed frame 1736 of 1814
# Processed frame 1737 of 1814
# Processed frame 1738 of 1814
# Processed frame 1739 of 1814
# Processed frame 1740 of 1814
# Processed frame 1741 of 1814
# Processed frame 1742 of 1814
# Processed frame 1743 of 1814
# Processed frame 1744 of 1814
# Processed frame 1745 of 1814
# Processed frame 1746 of 1814
# Processed frame 1747 of 1814
# Processed frame 1748 of 1814
# Processed frame 1749 of 1814
# Processed frame 1750 of 1814
# Processed frame 1751 of 1814
# Processed frame 1752 of 1814
# Processed frame 1753 of 1814
# Processed frame 1754 of 1814
# Processed frame 1755 of 1814
# Processed frame 1756 of 1814
# Processed frame 1757 of 1814
# Processed frame 1758 of 1814
# Processed frame 1759 of 1814
# Processed frame 1760 of 1814
# Processed frame 1761 of 1814
# Processed frame 1762 of 1814
# Processed frame 1763 of 1814
# Processed frame 1764 of 1814
# Processed frame 1765 of 1814
# Processed frame 1766 of 1814
# Processed frame 1767 of 1814
# Processed frame 1768 of 1814
# Processed frame 1769 of 1814
# Processed frame 1770 of 1814
# Processed frame 1771 of 1814
# Processed frame 1772 of 1814
# Processed frame 1773 of 1814
# Processed frame 1774 of 1814
# Processed frame 1775 of 1814
# Processed frame 1776 of 1814
# Processed frame 1777 of 1814
# Processed frame 1778 of 1814
# Processed frame 1779 of 1814
# Processed frame 1780 of 1814
# Processed frame 1781 of 1814
# Processed frame 1782 of 1814
# Processed frame 1783 of 1814
# Processed frame 1784 of 1814
# Processed frame 1785 of 1814
# Processed frame 1786 of 1814
# Processed frame 1787 of 1814
# Processed frame 1788 of 1814
# Processed frame 1789 of 1814
# Processed frame 1790 of 1814
# Processed frame 1791 of 1814
# Processed frame 1792 of 1814
# Processed frame 1793 of 1814
# Processed frame 1794 of 1814
# Processed frame 1795 of 1814
# Processed frame 1796 of 1814
# Processed frame 1797 of 1814
# Processed frame 1798 of 1814
# Processed frame 1799 of 1814
# Processed frame 1800 of 1814
# Processed frame 1801 of 1814
# Processed frame 1802 of 1814
# Processed frame 1803 of 1814
# Processed frame 1804 of 1814
# Processed frame 1805 of 1814
# Processed frame 1806 of 1814
# Processed frame 1807 of 1814
# Processed frame 1808 of 1814
# Processed frame 1809 of 1814
# Processed frame 1810 of 1814
# Processed frame 1811 of 1814
# Processed frame 1812 of 1814
# Processed frame 1813 of 1814
# Processed frame 1814 of 1814
# Video saved to /content/drive/MyDrive/Colab Notebooks/MediaPipe/results/processed_Green Screen Hand (20+ Effects 4K _ Free Download Link).mp4
#
# Enter your choice to proceed:
# 1: Image
# 2: Video
# 3: WebCam
# 0: Exit
# >0
# Good bye!
